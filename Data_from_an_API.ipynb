# %%
#importing Libraries

import pandas as pd
import numpy as np
import requests
import json

# %%
#urls
url_list=['https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1','https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=2','https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=3','https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=4','https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=5','https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=6','https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=7','https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=8','https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=9','https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=10']

# %%
JSONContent = requests.get(url).json()
content = json.dumps(JSONContent, indent = 4, sort_keys=True)
print(content)
# Out:
# {
#     "page": 10,
#     "results": [
#         {
#             "adult": false,
#             "backdrop_path": "/qdTTCAt35taHlFeeKZwBXLuJ5z7.jpg",
#             "genre_ids": [
#                 35,
#                 80,
#                 18
#             ],
#             "id": 9277,
#             "original_language": "en",
#             "original_title": "The Sting",
#             "overview": "Set in the 1930s this intricate caper deals with an ambitious small-time crook and a veteran con man who seek revenge on a vicious crime lord who murdered one of their gang.",
#             "popularity": 12.808,
#             "poster_path": "/mQaM8fDQdFWwCTFp0TZG8fChlZ5.jpg",
#             "release_date": "1973-12-25",
#             "title": "The Sting",
#             "video": false,
#             "vote_average": 8.1,
#             "vote_count": 1156
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/kBNMqlNh1sskJixIDdhbLZnBBjt.jpg",
#             "genre_ids": [
#                 35
#             ],
#             "id": 160885,
#             "original_language": "it",
#             "original_title": "Tel chi el tel\u00f9n",
#             "overview": "",
#             "popularity": 5.803,
#             "poster_path": "/hfVkk9FOJJkVps1ahdun4mq7m4J.jpg",
#             "release_date": "2009-03-01",
#             "title": "Tel chi el tel\u00f9n",
#             "video": false,
#             "vote_average": 8.1,
#             "vote_count": 209
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/qcb6z1HpokTOKdjqDTsnjJk0Xvg.jpg",
#             "genre_ids": [
#                 36,
#                 18,
#                 53,
#                 10752
#             ],
#             "id": 205596,
#             "original_language": "en",
#             "original_title": "The Imitation Game",
#             "overview": "Based on the real life story of legendary cryptanalyst Alan Turing, the film portrays the nail-biting race against time by Turing and his brilliant team of code-breakers at Britain's top-secret Government Code and Cypher School at Bletchley Park, during the darkest days of World War II.",
#             "popularity": 30.436,
#             "poster_path": "/noUp0XOqIcmgefRnRZa1nhtRvWO.jpg",
#             "release_date": "2014-12-19",
#             "title": "The Imitation Game",
#             "video": false,
#             "vote_average": 8.1,
#             "vote_count": 10730
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/bUXxR2fNjrfRtul2A6mf0ypY4Bu.jpg",
#             "genre_ids": [
#                 18,
#                 53
#             ],
#             "id": 582,
#             "original_language": "de",
#             "original_title": "Das Leben der Anderen",
#             "overview": "A tragic love story set in East Berlin with the backdrop of an undercover Stasi controlled culture. Stasi captain Wieler is ordered to follow author Dreyman and plunges deeper and deeper into his life until he reaches the threshold of doubting the system.",
#             "popularity": 8.812,
#             "poster_path": "/bzzDAg3fkztvfQB08VBprhs9tVE.jpg",
#             "release_date": "2006-06-06",
#             "title": "The Lives of Others",
#             "video": false,
#             "vote_average": 8.1,
#             "vote_count": 1762
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/lrIuSWdC1LfKJZUnBX6axJxzZGe.jpg",
#             "genre_ids": [
#                 9648,
#                 53
#             ],
#             "id": 1092,
#             "original_language": "en",
#             "original_title": "The Third Man",
#             "overview": "In postwar Vienna, Austria, Holly Martins, a writer of pulp Westerns, arrives penniless as a guest of his childhood chum Harry Lime, only to learn he has died. Martins develops a conspiracy theory after learning of a \"third man\" present at the time of Harry's death, running into interference from British officer Major Calloway, and falling head-over-heels for Harry's grief-stricken lover, Anna.",
#             "popularity": 11.904,
#             "poster_path": "/rO2Fq0AZZx9obs52KJdx4mRE8p5.jpg",
#             "release_date": "1950-02-02",
#             "title": "The Third Man",
#             "video": false,
#             "vote_average": 8.1,
#             "vote_count": 815
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/dfNrZ82poQ8blHWJreIv6JZQ9JA.jpg",
#             "genre_ids": [
#                 27,
#                 878
#             ],
#             "id": 348,
#             "original_language": "en",
#             "original_title": "Alien",
#             "overview": "During its return to the earth, commercial spaceship Nostromo intercepts a distress signal from a distant planet. When a three-member team of the crew discovers a chamber containing thousands of eggs on the planet, a creature inside one of the eggs attacks an explorer. The entire crew is unaware of the impending nightmare set to descend upon them when the alien parasite planted inside its unfortunate host is birthed.",
#             "popularity": 25.362,
#             "poster_path": "/2h00HrZs89SL3tXB4nbkiM7BKHs.jpg",
#             "release_date": "1979-05-25",
#             "title": "Alien",
#             "video": false,
#             "vote_average": 8.1,
#             "vote_count": 7829
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/1dXTsaFxHoF9cas08UjAqE8NqOW.jpg",
#             "genre_ids": [
#                 18,
#                 878,
#                 10749
#             ],
#             "id": 38,
#             "original_language": "en",
#             "original_title": "Eternal Sunshine of the Spotless Mind",
#             "overview": "Joel Barish, heartbroken that his girlfriend underwent a procedure to erase him from her memory, decides to do the same. However, as he watches his memories of her fade away, he realises that he still loves her, and may be too late to correct his mistake.",
#             "popularity": 15.322,
#             "poster_path": "/7y3eYvTsGjxPYDtSnumCLIMDkrV.jpg",
#             "release_date": "2004-03-19",
#             "title": "Eternal Sunshine of the Spotless Mind",
#             "video": false,
#             "vote_average": 8.1,
#             "vote_count": 7791
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/zGutQCLUIQ5LakubDZtfM8s22eA.jpg",
#             "genre_ids": [
#                 18,
#                 9648
#             ],
#             "id": 15,
#             "original_language": "en",
#             "original_title": "Citizen Kane",
#             "overview": "Newspaper magnate, Charles Foster Kane is taken from his mother as a boy and made the ward of a rich industrialist. As a result, every well-meaning, tyrannical or self-destructive move he makes for the rest of his life appears in some way to be a reaction to that deeply wounding event.",
#             "popularity": 12.086,
#             "poster_path": "/sav0jxhqiH0bPr2vZFU0Kjt2nZL.jpg",
#             "release_date": "1941-05-01",
#             "title": "Citizen Kane",
#             "video": false,
#             "vote_average": 8.1,
#             "vote_count": 2503
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/9yepEBnQNcKzWWyHdUiX8Mnqc6U.jpg",
#             "genre_ids": [
#                 18
#             ],
#             "id": 19426,
#             "original_language": "it",
#             "original_title": "Le notti di Cabiria",
#             "overview": "Rome, 1957. A woman, Cabiria, is robbed and left to drown by her boyfriend, Giorgio. Rescued, she resumes her life and tries her best to find happiness in a cynical world. Even when she thinks her struggles are over and she has found happiness and contentment, things may not be what they seem.",
#             "popularity": 6.706,
#             "poster_path": "/xF4oCG3PLNbcrtPZbqB3BtkIbKg.jpg",
#             "release_date": "1957-12-31",
#             "title": "Nights of Cabiria",
#             "video": false,
#             "vote_average": 8.1,
#             "vote_count": 255
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/tWYihe4jwkFdl38M62ZgrKtvBAx.jpg",
#             "genre_ids": [
#                 28,
#                 12,
#                 35,
#                 18
#             ],
#             "id": 1059,
#             "original_language": "ja",
#             "original_title": "\u96a0\u3057\u7826\u306e\u4e09\u60aa\u4eba",
#             "overview": "Japanese peasants Matashichi and Tahei try and fail to make a profit from a tribal war. They find a man and woman whom they believe are simple tribe members hiding in a fortress. Although the peasants don't know that Rokurota is a general and Yuki is a princess, the peasants agree to accompany the pair to safety in return for gold. Along the way, the general must prove his expertise in battle while also hiding his identity.",
#             "popularity": 9.232,
#             "poster_path": "/vWMZd6Uwt7loSR6lFRJLrnvO7Tt.jpg",
#             "release_date": "1958-12-28",
#             "title": "The Hidden Fortress",
#             "video": false,
#             "vote_average": 8.1,
#             "vote_count": 213
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/rR479zn26lJp4vNxXKjfBVCHLAW.jpg",
#             "genre_ids": [
#                 18,
#                 36
#             ],
#             "id": 1955,
#             "original_language": "en",
#             "original_title": "The Elephant Man",
#             "overview": "A Victorian surgeon rescues a heavily disfigured man being mistreated by his \"owner\" as a side-show freak. Behind his monstrous fa\u00e7ade, there is revealed a person of great intelligence and sensitivity. Based on the true story of Joseph Merrick (called John Merrick in the film), a severely deformed man in 19th century London.",
#             "popularity": 11.629,
#             "poster_path": "/lDXJUmLQsViSKLbil2luD91l2kE.jpg",
#             "release_date": "1980-10-03",
#             "title": "The Elephant Man",
#             "video": false,
#             "vote_average": 8.1,
#             "vote_count": 1552
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/vi8Td5ziicumFdPMUxA3Sd7j4Mz.jpg",
#             "genre_ids": [
#                 18
#             ],
#             "id": 81481,
#             "original_language": "ko",
#             "original_title": "\ub3c4\uac00\ub2c8",
#             "overview": "Based on actual events that took place at Gwangju Inhwa School for the hearing-impaired, where young deaf students were the victims of repeated sexual assaults by faculty members over a period of five years in the early 2000s.",
#             "popularity": 7.139,
#             "poster_path": "/5cRQ516LBcW4nPKxTX3F8u7otSZ.jpg",
#             "release_date": "2011-09-22",
#             "title": "Silenced",
#             "video": false,
#             "vote_average": 8.1,
#             "vote_count": 157
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/cqn1ynw78Wan37jzs1Ckm7va97G.jpg",
#             "genre_ids": [
#                 16,
#                 10751,
#                 10749
#             ],
#             "id": 140420,
#             "original_language": "en",
#             "original_title": "Paperman",
#             "overview": "An urban office worker finds that paper airplanes are instrumental in meeting a girl in ways he never expected.",
#             "popularity": 7.482,
#             "poster_path": "/3TpMBcAYH4cxCw5WoRacWodMTCG.jpg",
#             "release_date": "2012-11-02",
#             "title": "Paperman",
#             "video": false,
#             "vote_average": 8.1,
#             "vote_count": 1147
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/fBKXwJxK1c1WLI6NrYOmL5WEE3G.jpg",
#             "genre_ids": [
#                 18,
#                 35,
#                 10749
#             ],
#             "id": 18438,
#             "original_language": "ko",
#             "original_title": "\uae40\uc528 \ud45c\ub958\uae30",
#             "overview": "Mr. Kim is jobless, lost in debt and has been dumped by his girlfriend. He decides to end it all by jumping into the Han River - only to find himself washed up on a small, mid-river island. He soon abandons thoughts of suicide or rescue and begins a new life as a castaway. His antics catch the attention of a young woman whose apartment overlooks the river. Her discovery changes both their lives.",
#             "popularity": 6.388,
#             "poster_path": "/bqGgSOtz7d2TnDQEANwCZGmSaT2.jpg",
#             "release_date": "2010-02-05",
#             "title": "Castaway on the Moon",
#             "video": false,
#             "vote_average": 8.1,
#             "vote_count": 278
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/mc0PbKrrFRCUEpI09reR3ihHrIo.jpg",
#             "genre_ids": [
#                 18,
#                 36,
#                 10752
#             ],
#             "id": 387,
#             "original_language": "de",
#             "original_title": "Das Boot",
#             "overview": "A German submarine hunts allied ships during the Second World War, but it soon becomes the hunted. The crew tries to survive below the surface, while stretching both the boat and themselves to their limits.",
#             "popularity": 10.95,
#             "poster_path": "/kI1rptTkqDWj6SBRsYwguBvPViT.jpg",
#             "release_date": "1982-02-10",
#             "title": "Das Boot",
#             "video": false,
#             "vote_average": 8.1,
#             "vote_count": 1013
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/1s8oM0myujOb2pAHrfPaBZLqt6I.jpg",
#             "genre_ids": [
#                 18
#             ],
#             "id": 310569,
#             "original_language": "pt",
#             "original_title": "Que Horas Ela Volta?",
#             "overview": "After leaving her daughter Jessica in a small town in Pernambuco to be raised by relatives, Val spends the next 13 years working as a nanny to Fabinho in S\u00e3o Paulo. She has financial stability but has to live with the guilt of having not raised Jessica herself. As Fabinho\u2019s university entrance exams approach, Jessica reappears in her life and seems to want to give her mother a second chance. However Jessica has not been raised to be a servant and her very existence will turn Val\u2019s routine on its head. With precision and humour, Anna Muylaert turns her eye on the subtle and powerful forces that keep rigid class structures in place and how the youth may just be the ones to shake it all up.",
#             "popularity": 8.641,
#             "poster_path": "/hUrPe6AWWHbPYRAGKFUdeHjc9ck.jpg",
#             "release_date": "2015-08-28",
#             "title": "The Second Mother",
#             "video": false,
#             "vote_average": 8.1,
#             "vote_count": 368
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/xcaSYLBhmDzJ6P14bcKe0KTh3QV.jpg",
#             "genre_ids": [
#                 18,
#                 10402
#             ],
#             "id": 424694,
#             "original_language": "en",
#             "original_title": "Bohemian Rhapsody",
#             "overview": "Singer Freddie Mercury, guitarist Brian May, drummer Roger Taylor and bass guitarist John Deacon take the music world by storm when they form the rock 'n' roll band Queen in 1970. Hit songs become instant classics. When Mercury's increasingly wild lifestyle starts to spiral out of control, Queen soon faces its greatest challenge yet \u2013 finding a way to keep the band together amid the success and excess.",
#             "popularity": 41.875,
#             "poster_path": "/lHu1wtNaczFPGFDTrjCSzeLPTKN.jpg",
#             "release_date": "2018-11-02",
#             "title": "Bohemian Rhapsody",
#             "video": false,
#             "vote_average": 8.1,
#             "vote_count": 8405
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/sdNPipjZoOJFuTBwH8EyEb5dsKv.jpg",
#             "genre_ids": [
#                 18,
#                 53,
#                 12
#             ],
#             "id": 204,
#             "original_language": "fr",
#             "original_title": "Le salaire de la peur",
#             "overview": "In the South American jungle, supplies of nitroglycerine are needed at a remote oil field. The oil company pays four men to deliver the supplies in two trucks. A tense rivalry develops between the two sets of drivers on the rough remote roads where the slightest jolt can result in death.",
#             "popularity": 9.284,
#             "poster_path": "/3IGuAr1xsErR4XqmHZcfyQ4f8KY.jpg",
#             "release_date": "1955-02-16",
#             "title": "The Wages of Fear",
#             "video": false,
#             "vote_average": 8.1,
#             "vote_count": 335
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/wOvpMdPUftQ2LRTE0QmD8ExmEiF.jpg",
#             "genre_ids": [
#                 16,
#                 14
#             ],
#             "id": 32085,
#             "original_language": "en",
#             "original_title": "Vincent",
#             "overview": "Young Vincent Malloy dreams of being just like Vincent Price and loses himself in macabre daydreams that annoy his mother.",
#             "popularity": 5.947,
#             "poster_path": "/h64Zd7aWWGL1ctsU3W4i2rQOwTk.jpg",
#             "release_date": "1982-01-01",
#             "title": "Vincent",
#             "video": false,
#             "vote_average": 8,
#             "vote_count": 459
#         },
#         {
#             "adult": false,
#             "backdrop_path": "/g8yVrnJ72eOt1Xw4uyYBIsBBE2g.jpg",
#             "genre_ids": [
#                 18,
#                 36
#             ],
#             "id": 821,
#             "original_language": "en",
#             "original_title": "Judgment at Nuremberg",
#             "overview": "In 1947, four German judges who served on the bench during the Nazi regime face a military tribunal to answer charges of crimes against humanity. Chief Justice Haywood hears evidence and testimony not only from lead defendant Ernst Janning and his defense attorney Hans Rolfe, but also from the widow of a Nazi general, an idealistic U.S. Army captain and reluctant witness Irene Wallner.",
#             "popularity": 8.585,
#             "poster_path": "/iu7VMhBma5S94M3wh0fR8cmwgUf.jpg",
#             "release_date": "1961-12-19",
#             "title": "Judgment at Nuremberg",
#             "video": false,
#             "vote_average": 8,
#             "vote_count": 315
#         }
#     ],
#     "total_pages": 378,
#     "total_results": 7553
# }

# %%
popularity=[]
id=[]
vote_avg=[]
title=[]
release_date=[]
original_title=[]
overview=[]

# %%
for url in url_list:
    json_content= requests.get(url).json()
    content=json.dumps(json_content,indent=4,sort_keys=True)
    data=json.loads(content)
    for item in data['results']: 
        #extracting 'popularity'
        p=item['popularity']
        popularity.append(p)  
        #extracting 'id' 
        i=item['id']
        id.append(i)
        #extracting 'vote_average' 
        vote=item['vote_average']
        vote_avg.append(vote)
        #extracting 'title' 
        t=item['title']
        title.append(t)
        #extracting 'release_date' 
        r=item['release_date']
        release_date.append(r)
        #extracting 'original_title' 
        ot=item['original_title']
        original_title.append(ot)
        #extracting 'overview' 
        o=item['overview']
        overview.append(o)

# %%
#creating Dataframes

movies={}
movies['Id']=id
movies['Title']=title
movies['Release Date']=release_date
movies['Popularity']=popularity
movies['Vote Average']=vote_avg
movies['Original Title']=original_title
movies['Overview']=overview
movie_df = pd.DataFrame(data=movies)
movie_df.to_csv('Movies_info.csv')

# %%
movie_df.shape   #shape of dataframe
# Out:
# (200, 7)

# %%
movie_df
# Out:
#          Id                                          Title Release Date  \
# 0     19404                    Dilwale Dulhania Le Jayenge   1995-10-20
# 1       278                       The Shawshank Redemption   1994-09-23
# 2    496243                                       Parasite   2019-10-11
# 3       238                                  The Godfather   1972-03-15
# 4    372058                                     Your Name.   2017-04-07
# 5       424                               Schindler's List   1993-12-15
# 6       240                         The Godfather: Part II   1974-12-20
# 7       129                                  Spirited Away   2002-09-20
# 8       497                                 The Green Mile   1999-12-10
# 9       637                              Life Is Beautiful   1998-10-22
# 10      680                                   Pulp Fiction   1994-10-14
# 11   324857              Spider-Man: Into the Spider-Verse   2018-12-14
# 12      155                                The Dark Knight   2008-07-18
# 13       13                                   Forrest Gump   1994-07-06
# 14      550                                     Fight Club   1999-10-15
# 15      122  The Lord of the Rings: The Return of the King   2003-12-17
# 16      539                                         Psycho   1960-09-08
# 17    14537                                       Harakiri   1963-09-11
# 18      429                 The Good, the Bad and the Ugly   1967-12-29
# 19      769                                     GoodFellas   1990-09-19
# 20      311                    Once Upon a Time in America   1984-06-01
# 21      389                                   12 Angry Men   1957-04-10
# 22    11216                                Cinema Paradiso   2002-06-14
# 23      510                One Flew Over the Cuckoo's Nest   1975-11-18
# 24      346                                  Seven Samurai   1956-11-19
# 25    40096                                   A Dog's Will   2000-09-15
# 26      901                                    City Lights   1931-03-07
# 27   244786                                       Whiplash   2014-10-10
# 28    12477                         Grave of the Fireflies   2019-01-01
# 29      598                                    City of God   2002-08-31
# ..      ...                                            ...          ...
# 170     603                                     The Matrix   1999-03-30
# 171  324786                                  Hacksaw Ridge   2016-11-04
# 172   11712                                        Sanjuro   1963-05-07
# 173    7345                            There Will Be Blood   2007-12-28
# 174   11104                              Chungking Express   1994-09-15
# 175   30588                               Monsieur Verdoux   1947-04-11
# 176   46738                                      Incendies   2010-09-04
# 177   11423                             Memories of Murder   2003-04-24
# 178  491480                 The Boy Who Harnessed the Wind   2019-03-01
# 179    1394                                      Nostalgia   1983-10-05
# 180    9277                                      The Sting   1973-12-25
# 181  160885                               Tel chi el telùn   2009-03-01
# 182  205596                             The Imitation Game   2014-12-19
# 183     582                            The Lives of Others   2006-06-06
# 184    1092                                  The Third Man   1950-02-02
# 185     348                                          Alien   1979-05-25
# 186      38          Eternal Sunshine of the Spotless Mind   2004-03-19
# 187      15                                   Citizen Kane   1941-05-01
# 188   19426                              Nights of Cabiria   1957-12-31
# 189    1059                            The Hidden Fortress   1958-12-28
# 190    1955                               The Elephant Man   1980-10-03
# 191   81481                                       Silenced   2011-09-22
# 192  140420                                       Paperman   2012-11-02
# 193   18438                           Castaway on the Moon   2010-02-05
# 194     387                                       Das Boot   1982-02-10
# 195  310569                              The Second Mother   2015-08-28
# 196  424694                              Bohemian Rhapsody   2018-11-02
# 197     204                              The Wages of Fear   1955-02-16
# 198   32085                                        Vincent   1982-01-01
# 199     821                          Judgment at Nuremberg   1961-12-19
#
#      Popularity  Vote Average                                 Original Title  \
# 0        14.652           8.9                   दिलवाले दुल्हनिया ले जायेंगे
# 1        29.604           8.7                       The Shawshank Redemption
# 2        40.342           8.7                                            기생충
# 3        29.094           8.6                                  The Godfather
# 4        25.766           8.6                                          君の名は。
# 5        26.470           8.5                               Schindler's List
# 6        21.145           8.5                         The Godfather: Part II
# 7        28.933           8.5                                       千と千尋の神隠し
# 8        23.751           8.5                                 The Green Mile
# 9        16.022           8.5                                La vita è bella
# 10       27.083           8.4                                   Pulp Fiction
# 11       49.767           8.4              Spider-Man: Into the Spider-Verse
# 12       30.522           8.4                                The Dark Knight
# 13       24.968           8.4                                   Forrest Gump
# 14       38.326           8.4                                     Fight Club
# 15       36.247           8.4  The Lord of the Rings: The Return of the King
# 16       20.063           8.4                                         Psycho
# 17        8.431           8.4                                             切腹
# 18       21.983           8.4                Il buono, il brutto, il cattivo
# 19       24.834           8.4                                     GoodFellas
# 20       16.104           8.4                    Once Upon a Time in America
# 21       16.352           8.4                                   12 Angry Men
# 22       11.653           8.4                          Nuovo Cinema Paradiso
# 23       21.793           8.4                One Flew Over the Cuckoo's Nest
# 24       15.895           8.4                                           七人の侍
# 25        8.539           8.4                          O Auto da Compadecida
# 26        8.328           8.4                                    City Lights
# 27       33.598           8.4                                       Whiplash
# 28        0.600           8.4                                          火垂るの墓
# 29       12.120           8.4                                 Cidade de Deus
# ..          ...           ...                                            ...
# 170      43.623           8.1                                     The Matrix
# 171      20.164           8.1                                  Hacksaw Ridge
# 172       7.859           8.1                                           椿三十郎
# 173      15.436           8.1                            There Will Be Blood
# 174      11.460           8.1                                           重慶森林
# 175       8.879           8.1                               Monsieur Verdoux
# 176       8.420           8.1                                      Incendies
# 177      13.318           8.1                                         살인의 추억
# 178      11.056           8.1                 The Boy Who Harnessed the Wind
# 179       8.878           8.1                                     Nostalghia
# 180      12.808           8.1                                      The Sting
# 181       5.803           8.1                               Tel chi el telùn
# 182      30.436           8.1                             The Imitation Game
# 183       8.812           8.1                          Das Leben der Anderen
# 184      11.904           8.1                                  The Third Man
# 185      25.362           8.1                                          Alien
# 186      15.322           8.1          Eternal Sunshine of the Spotless Mind
# 187      12.086           8.1                                   Citizen Kane
# 188       6.706           8.1                            Le notti di Cabiria
# 189       9.232           8.1                                        隠し砦の三悪人
# 190      11.629           8.1                               The Elephant Man
# 191       7.139           8.1                                            도가니
# 192       7.482           8.1                                       Paperman
# 193       6.388           8.1                                         김씨 표류기
# 194      10.950           8.1                                       Das Boot
# 195       8.641           8.1                           Que Horas Ela Volta?
# 196      41.875           8.1                              Bohemian Rhapsody
# 197       9.284           8.1                          Le salaire de la peur
# 198       5.947           8.0                                        Vincent
# 199       8.585           8.0                          Judgment at Nuremberg
#
#                                               Overview
# 0    Raj is a rich, carefree, happy-go-lucky second...
# 1    Framed in the 1940s for the double murder of h...
# 2    All unemployed, Ki-taek's family takes peculia...
# 3    Spanning the years 1945 to 1955, a chronicle o...
# 4    High schoolers Mitsuha and Taki are complete s...
# 5    The true story of how businessman Oskar Schind...
# 6    In the continuing saga of the Corleone crime f...
# 7    A young girl, Chihiro, becomes trapped in a st...
# 8    A supernatural tale set on death row in a Sout...
# 9    A touching story of an Italian book seller of ...
# 10   A burger-loving hit man, his philosophical par...
# 11   Miles Morales is juggling his life between bei...
# 12   Batman raises the stakes in his war on crime. ...
# 13   A man with a low IQ has accomplished great thi...
# 14   A ticking-time-bomb insomniac and a slippery s...
# 15   Aragorn is revealed as the heir to the ancient...
# 16   When larcenous real estate clerk Marion Crane ...
# 17   Aging samurai Hanshiro Tsugumo arrives at the ...
# 18   While the Civil War rages between the Union an...
# 19   The true story of Henry Hill, a half-Irish, ha...
# 20   A former Prohibition-era Jewish gangster retur...
# 21   The defense and the prosecution have rested an...
# 22   A filmmaker recalls his childhood, when he fel...
# 23   While serving time for insanity at a state men...
# 24   A samurai answers a village's request for prot...
# 25   The lively João Grilo and the sly Chicó are po...
# 26   City Lights is the first silent film that Char...
# 27   Under the direction of a ruthless instructor, ...
# 28   In the final months of World War II, 14-year-o...
# 29   Cidade de Deus is a shantytown that started du...
# ..                                                 ...
# 170  Set in the 22nd century, The Matrix tells the ...
# 171  WWII American Army Medic Desmond T. Doss, who ...
# 172  Toshiro Mifune swaggers and snarls to brillian...
# 173  Ruthless silver miner, turned oil prospector, ...
# 174  Two melancholic Hong Kong policemen fall in lo...
# 175  The film is about an unemployed banker, Henri ...
# 176  A mother's last wishes send twins Jeanne and S...
# 177  1986 Gyunggi Province. The body of a young wom...
# 178  Against all the odds, a thirteen year old boy ...
# 179  The Russian poet Andrei Gorchakov, accompanied...
# 180  Set in the 1930s this intricate caper deals wi...
# 181
# 182  Based on the real life story of legendary cryp...
# 183  A tragic love story set in East Berlin with th...
# 184  In postwar Vienna, Austria, Holly Martins, a w...
# 185  During its return to the earth, commercial spa...
# 186  Joel Barish, heartbroken that his girlfriend u...
# 187  Newspaper magnate, Charles Foster Kane is take...
# 188  Rome, 1957. A woman, Cabiria, is robbed and le...
# 189  Japanese peasants Matashichi and Tahei try and...
# 190  A Victorian surgeon rescues a heavily disfigur...
# 191  Based on actual events that took place at Gwan...
# 192  An urban office worker finds that paper airpla...
# 193  Mr. Kim is jobless, lost in debt and has been ...
# 194  A German submarine hunts allied ships during t...
# 195  After leaving her daughter Jessica in a small ...
# 196  Singer Freddie Mercury, guitarist Brian May, d...
# 197  In the South American jungle, supplies of nitr...
# 198  Young Vincent Malloy dreams of being just like...
# 199  In 1947, four German judges who served on the ...
#
# [200 rows x 7 columns]

# %%
movie_df.columns  #list of columns
# Out:
# Index(['Id', 'Title', 'Release Date', 'Popularity', 'Vote Average',
#        'Original Title', 'Overview'],
#       dtype='object')

# %%
movie_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 7 columns):
# Id                200 non-null int64
# Title             200 non-null object
# Release Date      200 non-null object
# Popularity        200 non-null float64
# Vote Average      200 non-null float64
# Original Title    200 non-null object
# Overview          200 non-null object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 11.0+ KB
